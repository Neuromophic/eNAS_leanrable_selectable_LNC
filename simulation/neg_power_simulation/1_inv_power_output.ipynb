# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Power_new_negwt.csv')
data
# Out:
#         X  \
# 0   -2.00
# 1   -1.99
# 2   -1.98
# 3   -1.97
# 4   -1.96
# ..    ...
# 396  1.96
# 397  1.97
# 398  1.98
# 399  1.99
# 400  2.00
#
#      Power (R1_data=1150000,R2_data=19000,W1_data=9e-05,L1_data=6e-05,W2_data=0.00049,L2_data=3.5e-05,R_inv=400000,W_inv=0.00014,L_inv=0.0001) Y  \
# 0                                             0.000021
# 1                                             0.000021
# 2                                             0.000021
# 3                                             0.000021
# 4                                             0.000021
# ..                                                 ...
# 396                                           0.000200
# 397                                           0.000200
# 398                                           0.000200
# 399                                           0.000200
# 400                                           0.000200
#
# ...

# %%
a = torch.tensor(data.to_numpy())[:,1:].mean(dim=0)
a.shape
# Out:
# torch.Size([9999])

# %%
torch.save(a, './data/neg_power.data')
