# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Vout_hard_sigmoid.csv')
data
# Out:
#         X  /Out (L=0.00027,R=5100000,w=0.0006) Y  \
# 0   -2.00                           7.670000e-17
# 1   -1.99                           1.100000e-16
# 2   -1.98                           1.430000e-16
# 3   -1.97                           1.760000e-16
# 4   -1.96                           2.090000e-16
# ..    ...                                    ...
# 396  1.96                           9.984800e-01
# 397  1.97                           9.984900e-01
# 398  1.98                           9.984900e-01
# 399  1.99                           9.985000e-01
# 400  2.00                           9.985000e-01
#
#      /Out (L=0.000155,R=7550000,w=0.0004) Y  \
# 0                              1.320000e-16
# 1                              1.890000e-16
# 2                              2.450000e-16
# 3                              3.020000e-16
# 4                              3.590000e-16
# ..                                      ...
# 396                            9.991200e-01
# ...

# %% [markdown]
# # 无用列

# %%
a = torch.tensor(data.to_numpy())[:,1:]
a.shape
# Out:
# torch.Size([401, 9999])

# %%
torch.save(a, './data/hard_sigmoid_vout.data')
