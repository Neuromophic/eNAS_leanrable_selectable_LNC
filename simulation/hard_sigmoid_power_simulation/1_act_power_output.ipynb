# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Power_hard_sigmoid.csv')
data
# Out:
#         X  power (L=0.00027,R=5100000,w=0.0006) Y  \
# 0   -2.00                            1.150000e-39
# 1   -1.99                            3.860000e-39
# 2   -1.98                            6.560000e-39
# 3   -1.97                            9.270000e-39
# 4   -1.96                            1.200000e-38
# ..    ...                                     ...
# 396  1.96                            1.950000e-07
# 397  1.97                            1.950000e-07
# 398  1.98                            1.950000e-07
# 399  1.99                            1.950000e-07
# 400  2.00                            1.950000e-07
#
#      power (L=0.000155,R=7550000,w=0.0004) Y  \
# 0                               2.300000e-39
# 1                               7.700000e-39
# 2                               1.310000e-38
# 3                               1.850000e-38
# 4                               2.390000e-38
# ..                                       ...
# ...

# %%
a = torch.tensor(data.to_numpy())[:,1:].mean(dim=0)
a.shape
# Out:
# torch.Size([9999])

# %%
torch.save(a, './data/hard_sigmoid_power.data')
