# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Vout_pReLU.csv')
data
# Out:
#         X  \
# 0   -2.00
# 1   -1.99
# 2   -1.98
# 3   -1.97
# 4   -1.96
# ..    ...
# 396  1.96
# 397  1.97
# 398  1.98
# 399  1.99
# 400  2.00
#
#      /Out (RH2=77500,RL2=875000,RD2=5750,Rbase=47500,w=0.00065,L=0.00011) Y  \
# 0                                             -0.06453
# 1                                             -0.06397
# 2                                             -0.06341
# 3                                             -0.06285
# 4                                             -0.06229
# ..                                                 ...
# 396                                            0.93770
# 397                                            0.94340
# 398                                            0.94920
# 399                                            0.95500
# 400                                            0.96080
#
#      /Out (RH2=32500,RL2=1625000,RD2=15250,Rbase=82500,w=0.00035,L=9e-05) Y  \
# 0                                             -0.03817
# ...

# %% [markdown]
# # 无用列

# %%
a = torch.tensor(data.to_numpy())[:,1:]
a.shape
# Out:
# torch.Size([401, 9999])

# %%
torch.save(a, './data/pReLU_vout.data')
