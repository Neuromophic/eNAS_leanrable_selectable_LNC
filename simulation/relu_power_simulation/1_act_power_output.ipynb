# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Power_pReLU.csv')
data
# Out:
#         X  \
# 0   -2.00
# 1   -1.99
# 2   -1.98
# 3   -1.97
# 4   -1.96
# ..    ...
# 396  1.96
# 397  1.97
# 398  1.98
# 399  1.99
# 400  2.00
#
#      power (RH2=77500,RL2=875000,RD2=5750,Rbase=47500,w=0.00065,L=0.00011) Y  \
# 0                                             0.000089
# 1                                             0.000088
# 2                                             0.000087
# 3                                             0.000086
# 4                                             0.000085
# ..                                                 ...
# 396                                           0.000235
# 397                                           0.000238
# 398                                           0.000240
# 399                                           0.000243
# 400                                           0.000246
#
#      power (RH2=32500,RL2=1625000,RD2=15250,Rbase=82500,w=0.00035,L=9e-05) Y  \
# 0                                             0.000051
# ...

# %%
a = torch.tensor(data.to_numpy())[:,1:].mean(dim=0)
a.shape
# Out:
# torch.Size([9999])

# %%
torch.save(a, './data/pReLU_power.data')
