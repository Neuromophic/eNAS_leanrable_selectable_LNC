# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Vout_sigmoid.csv')
data
# Out:
#         X  \
# 0   -2.00
# 1   -1.99
# 2   -1.98
# 3   -1.97
# 4   -1.96
# ..    ...
# 396  1.96
# 397  1.97
# 398  1.98
# 399  1.99
# 400  2.00
#
#      /Vout (R1_data=650000,R2_data=50000,W1_data=0.00021,L1_data=0.00011,W2_data=0.000725,L2_data=7e-05) Y  \
# 0                                              0.05294
# 1                                              0.05294
# 2                                              0.05294
# 3                                              0.05294
# 4                                              0.05294
# ..                                                 ...
# 396                                            0.99980
# 397                                            0.99980
# 398                                            0.99980
# 399                                            0.99980
# 400                                            0.99980
#
# ...

# %% [markdown]
# # 无用列

# %%
a = torch.tensor(data.to_numpy())[:,1:]
a.shape
# Out:
# torch.Size([401, 9999])

# %%
torch.save(a, './data/sigmoid_vout.data')
