# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./data/Power_sigmoid.csv')
data
# Out:
#         X  \
# 0   -2.00
# 1   -1.99
# 2   -1.98
# 3   -1.97
# 4   -1.96
# ..    ...
# 396  1.96
# 397  1.97
# 398  1.98
# 399  1.99
# 400  2.00
#
#      Power (R1_data=550000,R2_data=60000,W1_data=0.00034,L1_data=0.00014,W2_data=0.00065,L2_data=6e-05) Y  \
# 0                                             0.000015
# 1                                             0.000015
# 2                                             0.000015
# 3                                             0.000015
# 4                                             0.000015
# ..                                                 ...
# 396                                           0.000002
# 397                                           0.000002
# 398                                           0.000002
# 399                                           0.000002
# 400                                           0.000002
#
# ...

# %%
a = torch.tensor(data.to_numpy())[:,1:].mean(dim=0)
a.shape
# Out:
# torch.Size([9999])

# %%
torch.save(a, './data/sigmoid_power.data')
